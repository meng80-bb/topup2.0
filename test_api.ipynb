# %%
import requests

base_url = "http://127.0.0.1:5000/api/tasks"
params = {
    "user_id": "user123",
    "limit": 10,
    "offset": 0,
}

resp = requests.get(base_url, params=params)
print(resp.status_code, resp.text)
# Out:
# 200 {
#   "limit": 10,
#   "offset": 0,
#   "success": true,
#   "tasks": [
#     {
#       "completed_at": null,
#       "created_at": "2026-03-01T09:21:03.387743",
#       "current_step": null,
#       "date_param": null,
#       "error_message": null,
#       "estimated_completion_time": null,
#       "id": 4,
#       "progress_percentage": 0,
#       "started_at": null,
#       "status": "pending",
#       "task_name": "step1\u6d4b\u8bd5",
#       "user_id": "user123",
#       "workflow_id": 1
#     },
#     {
#       "completed_at": "2026-03-01T07:41:25.316200",
#       "created_at": "2026-03-01T07:41:12.602314",
#       "current_step": null,
#       "date_param": null,
#       "error_message": null,
#       "estimated_completion_time": null,
#       "id": 3,
#       "progress_percentage": 100,
#       "started_at": "2026-03-01T07:41:24.987733",
#       "status": "success",
#       "task_name": "\u83b7\u53d6\u53ef\u7528\u65e5\u671f\u5217\u8868",
#       "user_id": "user123",
#       "workflow_id": 3
#     },
#     {
#       "completed_at": "2026-03-01T07:31:43.491781",
#       "created_at": "2026-03-01T07:31:27.787531",
#       "current_step": null,
#       "date_param": null,
#       "error_message": null,
#       "estimated_completion_time": null,
#       "id": 2,
#       "progress_percentage": 100,
#       "started_at": "2026-03-01T07:31:42.824670",
#       "status": "success",
#       "task_name": "\u83b7\u53d6\u53ef\u7528\u65e5\u671f\u5217\u8868",
#       "user_id": "user123",
#       "workflow_id": 3
#     },
#     {
#       "completed_at": "2026-03-01T06:55:29.195124",
#       "created_at": "2026-03-01T06:54:10.198274",
#       "current_step": null,
#       "date_param": null,
#       "error_message": null,
#       "estimated_completion_time": null,
#       "id": 1,
#       "progress_percentage": 100,
#       "started_at": "2026-03-01T06:55:28.652911",
#       "status": "success",
#       "task_name": "\u83b7\u53d6\u53ef\u7528\u65e5\u671f\u5217\u8868",
#       "user_id": "user123",
#       "workflow_id": 3
#     }
#   ],
#   "total": 4
# }

# %%
import requests

url = "http://127.0.0.1:5000/api/tasks"  # 修改为实际的地址
payload = {
    "user_id": "user123",
    "workflow_name": "get_available_dates_workflow",
    "task_name": "获取可用日期列表",
    "parameters": {
        "include_processed": False,
        "user_id": "user123",
        "sort_order": "asc",
        "round": "round18"
    }
}

resp = requests.post(url, json=payload)  # requests 会自动设置 Content-Type: application/json
print(resp.status_code, resp.text)
# Out:
# 201 {
#   "message": "Task created successfully",
#   "status": "pending",
#   "success": true,
#   "task": {
#     "completed_at": null,
#     "created_at": "2026-03-01T07:41:12.602314",
#     "current_step": null,
#     "date_param": null,
#     "error_message": null,
#     "estimated_completion_time": null,
#     "id": 3,
#     "progress_percentage": 0,
#     "started_at": null,
#     "status": "pending",
#     "task_name": "\u83b7\u53d6\u53ef\u7528\u65e5\u671f\u5217\u8868",
#     "user_id": "user123",
#     "workflow_id": 3
#   },
#   "task_id": 3
# }

# %%
import requests
import json

base_url = "http://127.0.0.1:5000/api/tasks/4"


resp = requests.get(base_url)
# 吧resp.text中的\uXXXX转成正常的中文
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "task": {
#         "completed_at": null,
#         "created_at": "2026-03-01T09:21:03.387743",
#         "current_step": null,
#         "date_param": null,
#         "error_message": null,
#         "estimated_completion_time": null,
#         "executions": [
#             {
#                 "created_at": "2026-03-01T10:01:51.541151",
#                 "duration_seconds": null,
#                 "end_time": null,
#                 "error_details": null,
#                 "id": 4,
#                 "output_summary": null,
#                 "retry_count": 0,
#                 "start_time": "2026-03-01T10:01:51.532071",
#                 "status": "running",
#                 "step_display_name": "第一次作业提交并检查结果文件",
#                 "step_name": "step1_1",
#                 "step_order": 1,
#                 "task_id": 4
#             }
#         ],
#         "id": 4,
#         "parameters": {
#             "check_ist": "True",
#             "date": "250519",
#             "download_files": "True",
#             "max_wait_minutes": "30",
#             "round": "round18",
#             "submit_job": "True",
#             "user_id": "user123"
#         },
#         "progress_percentage": 0,
#         "started_at": "2026-03-01T10:01:51.484005",
#         "status": "running",
#         "task_name": "step1测试",
#         "user_id": "user123",
#         "workflow_id": 1
#     }
# }

# %%
# hit the start endpoint for the task referenced by `base_url`
import requests

start_url = "http://127.0.0.1:5000/api/tasks/4/start"     # e.g. http://127.0.0.1:5000/api/tasks/1/start
resp = requests.post(start_url)  # send any needed params/body

print(resp.status_code, resp.text)
# Out:
# 200 {
#   "message": "Task started",
#   "success": true,
#   "task_id": 4
# }

# %%
# hit the start endpoint for the task referenced by `base_url`
import requests

start_url = "http://127.0.0.1:5000/api/tasks/1/pause"     # e.g. http://127.0.0.1:5000/api/tasks/1/start
resp = requests.post(start_url)  # send any needed params/body

print(resp.status_code, resp.text)
# Out:
# 400 {
#   "error": "Cannot pause task in running state",
#   "success": false
# }

# %%
# fetch error‑level logs for this task
import requests
base_url = "http://127.0.0.1:5000/api/tasks/1"  # e.g. http://
logs_url = f"{base_url}/logs"
query_params = {"limit": 100}

resp = requests.get(logs_url, params=query_params)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "logs": [
#         {
#             "created_at": "2026-03-01T06:55:29.155181",
#             "execution_id": 1,
#             "id": 1,
#             "level": "info",
#             "message": "Step 获取可用日期列表 completed successfully",
#             "source": "step_executor.step0",
#             "task_id": 1,
#             "timestamp": "2026-03-01T06:55:29.155178"
#         }
#     ],
#     "success": true,
#     "total": 1
# }

# %%
# fetch error‑level logs for this task
import requests
base_url = "http://127.0.0.1:5000/api/workflows"  # e.g. http://


resp = requests.get(base_url)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "workflows": [
#         {
#             "config_path": "/home/insolitude/topup2.0/HttpBackend/workflows/topup_standard_steps.json",
#             "created_at": "2026-03-01T05:50:37.804026",
#             "description": "执行完整的Topup数据处理流程：第一次作业提交、移动文件、IST分析和图片合并",
#             "id": 1,
#             "name": "topup_standard_steps_workflow",
#             "status": "active",
#             "updated_at": "2026-03-01T05:50:37.804030",
#             "version": "1.0.0"
#         },
#         {
#             "config_path": "/home/insolitude/topup2.0/HttpBackend/workflows/topup_standard.json",
#             "created_at": "2026-03-01T05:50:37.830658",
#             "description": "完整的数据处理流程，包含步骤1-8的所有子步骤",
#             "id": 2,
#             "name": "topup_standard_workflow",
#             "status": "active",
#             "updated_at": "2026-03-01T05:50:37.830662",
#             "version": "1.0.0"
#         },
#         {
#             "config_path": "/home/insolitude/topup2.0/HttpBackend/workflows/get_available_dates.json",
#             "created_at": "2026-03-01T05:50:37.855166",
#             "description": "获取数据目录中所有可用的日期列表，并可选择包含已处理日期信息",
#             "id": 3,
#             "name": "get_available_dates_workflow",
#             "status": "active",
#             "updated_at": "2026-03-01T05:50:37.855169",
#             "version": "1.0.1"
#         }
#     ]
# }

# %%
# fetch error‑level logs for this task
import requests
import json
base_url = "http://127.0.0.1:5000/api/workflows/topup_standard_steps_workflow"  # e.g. http://

resp = requests.get(base_url)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "workflow": {
#         "description": "执行完整的Topup数据处理流程：第一次作业提交、移动文件、IST分析和图片合并",
#         "execution_config": {
#             "cleanup_on_failure": false,
#             "cleanup_on_success": false,
#             "continue_on_error": false,
#             "default_timeout_minutes": 60,
#             "max_parallel_tasks": 1,
#             "max_retries": 2,
#             "retry_delay_seconds": 30,
#             "retry_on_failure": true
#         },
#         "name": "topup_standard_steps_workflow",
#         "parameters_config": {
#             "optional": [
#                 {
#                     "default": true,
#                     "description": "是否提交作业，默认为True",
#                     "name": "submit_job",
#                     "type": "boolean"
#                 },
#                 {
#                     "default": 25,
#                     "description": "最大等待时间（分钟），默认25分钟",
#                     "name": "max_wait_minutes",
#                     "type": "integer"
#                 },
#                 {
#                     "default": true,
#                     "description": "是否检查IST值是否等于15000000，默认为True",
#                     "name": "check_ist",
#                     "type": "boolean"
#                 },
#                 {
#                     "default": true,
#                     "description": "是否下载PDF文件到本地，默认为True",
#                     "name": "download_files",
#                     "type": "boolean"
#                 }
#             ],
#             "required": [
#                 "user_id",
#                 "date",
#                 "round"
#             ]
#         },
#         "steps": [
#             {
#                 "description": "提交作业并监控结果文件生成，检查6个必需文件",
#                 "display_name": "第一次作业提交并检查结果文件",
#                 "function": "step1_1_first_job_submission",
#                 "id": "step1_1",
#                 "module": "topup_step_v1.step1_1_first_job_submission",
#                 "order": 1,
#                 "parameters": {
#                     "date": "date",
#                     "max_wait_minutes": "max_wait_minutes",
#                     "round": "round",
#                     "submit_job": "submit_job"
#                 },
#                 "retry_count": 2,
#                 "timeout_minutes": 30
#             },
#             {
#                 "description": "将root文件移动到calibConst目录，将png文件移动到Interval_plot目录",
#                 "display_name": "移动文件",
#                 "function": "step1_2_move_files",
#                 "id": "step1_2",
#                 "module": "topup_step_v1.step1_2_move_files",
#                 "order": 2,
#                 "parameters": {
#                     "date": "date",
#                     "round": "round"
#                 },
#                 "retry_count": 2,
#                 "timeout_minutes": 5
#             },
#             {
#                 "description": "检查每个run号的Interval文件中的interval值，验证是否都等于15000000",
#                 "display_name": "IST分析",
#                 "function": "step1_3_ist_analysis",
#                 "id": "step1_3",
#                 "module": "topup_step_v1.step1_3_ist_analysis",
#                 "order": 3,
#                 "parameters": {
#                     "check": "check_ist",
#                     "date": "date",
#                     "round": "round"
#                 },
#                 "retry_count": 2,
#                 "timeout_minutes": 10
#             },
#             {
#                 "description": "进入Interval_plot目录，使用容器中的convert命令将所有PNG图片合并为PDF",
#                 "display_name": "合并图片",
#                 "function": "step1_4_merge_images",
#                 "id": "step1_4",
#                 "module": "topup_step_v1.step1_4_merge_images",
#                 "order": 4,
#                 "parameters": {
#                     "date": "date",
#                     "download_files": "download_files",
#                     "round": "round"
#                 },
#                 "retry_count": 2,
#                 "timeout_minutes": 15
#             }
#         ],
#         "version": "1.0.0"
#     }
# }

# %%
import requests
import json

url = "http://127.0.0.1:5000/api/tasks"  # 修改为实际的地址
payload = {
    "user_id": "user123",
    "workflow_name": "topup_standard_steps_workflow",
    "task_name": "step1测试",
    "parameters": {
        "user_id": "user123",
        "submit_job": True,
        "check_ist" : True,
        "max_wait_minutes": 30,
        "download_files" : True,
        "date" : 250519,
        "round": "round18"
    }
}

resp = requests.post(url, json=payload)  # requests 会自动设置 Content-Type: application/json


resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#       4 payload = {
#       5     "user_id": "user123",
#       6     "workflow_name": "topup_standard_steps_workflow",
#    (...)     16     }
#      17 }
#      19 resp = requests.post(url, json=payload)  # requests 会自动设置 Content-Type: application/json
# ---> 22 resp_text = json.loads(resp.text)
#      23 print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
#
# NameError: name 'json' is not defined
