# %%
import requests

base_url = "http://127.0.0.1:5000/api/tasks"
params = {
    "user_id": "HuYuXuan",
    "limit": 10,
    "offset": 0,
}

resp = requests.get(base_url, params=params)
print(resp.status_code, resp.text)
# Out:
# 200 {
#   "limit": 10,
#   "offset": 0,
#   "success": true,
#   "tasks": [],
#   "total": 0
# }

# %%
import requests

url = "http://127.0.0.1:5000/api/tasks"  # 修改为实际的地址
payload = {
    "user_id": "user123",
    "workflow_name": "get_available_dates_workflow",
    "task_name": "获取可用日期列表",
    "parameters": {
        "include_processed": False,
        "user_id": "user123",
        "sort_order": "asc",
        "round": "round18"
    }
}

resp = requests.post(url, json=payload)  # requests 会自动设置 Content-Type: application/json
print(resp.status_code, resp.text)
# Out:
# 201 {
#   "message": "Task created successfully",
#   "status": "pending",
#   "success": true,
#   "task": {
#     "completed_at": null,
#     "created_at": "2026-03-06T10:30:06.748248",
#     "current_step": null,
#     "date_param": null,
#     "error_message": null,
#     "estimated_completion_time": null,
#     "id": 1,
#     "pause_at_step": null,
#     "progress_percentage": 0,
#     "resume_from_step": null,
#     "started_at": null,
#     "status": "pending",
#     "task_name": "\u83b7\u53d6\u53ef\u7528\u65e5\u671f\u5217\u8868",
#     "user_id": "user123",
#     "workflow_id": 3
#   },
#   "task_id": 1
# }

# %%
import requests
import json

base_url = "http://127.0.0.1:5000/api/tasks/1"


resp = requests.get(base_url)
# 吧resp.text中的\uXXXX转成正常的中文
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "task": {
#         "completed_at": "2026-03-06T10:33:50.779493",
#         "created_at": "2026-03-06T10:30:06.748248",
#         "current_step": null,
#         "date_param": null,
#         "error_message": null,
#         "estimated_completion_time": null,
#         "executions": [
#             {
#                 "console_output": "============================================================\n步骤0：获取所有可用数据目录的日期列表\n============================================================\n包含已处理日期信息: False\n排序方式: asc\n\n获取所有可用数据目录...\n数据目录: /bes3fs/offline/data/cal/round18\n找到 74 个可用日期目录\n日期列表: ['250519', '250520', '250521', '250522', '250523', '250524', '250525', '250526', '250527', '250528', '250529', '250530', '250531', '250601', '250602', '250603', '250605', '250606', '250607', '250608', '250609', '250610', '250611', '250612', '250613', '250614', '250615', '250616', '250617', '250618', '250619', '250620', '250621', '250622', '250623', '250624', '250625', '250626', '250627', '250628', '250629', '250630', '250701', '250703', '250704', '250705', '250706', '250707', '250708', '250709', '250710', '250711', '250712', '250713', '250714', '250715', '250716', '250717', '250718', '250719', '250720', '250721', '250722', '250723', '250724', '250725', '250726', '250727', '250728', '250729', '250730', '250731', '250801', '250802']\n\n统计信息:\n  总日期数: 74",
#                 "created_at": "2026-03-06T10:30:19.479309",
#                 "duration_seconds": 0,
#                 "end_time": "2026-03-06T10:30:19.695998",
#                 "error_details": null,
#                 "id": 1,
#                 "output_summary": "成功获取 74 个可用日期",
#                 "retry_count": 0,
#                 "start_time": "2026-03-06T10:30:19.478401",
#                 "status": "success",
#                 "step_display_name": "获取可用日期列表",
#                 "step_name": "step0",
#                 "step_order": 1,
#                 "step_result_json": {
#                     "all_dates": [
#                         "250519",
#                         "250520",
#                         "250521",
#                         "250522",
#                         "250523",
#                         "250524",
#                         "250525",
#                         "250526",
#                         "250527",
#                         "250528",
#                         "250529",
#                         "250530",
#                         "250531",
#                         "250601",
#                         "250602",
#                         "250603",
#                         "250605",
#                         "250606",
#                         "250607",
#                         "250608",
#                         "250609",
#                         "250610",
#                         "250611",
#                         "250612",
#                         "250613",
#                         "250614",
#                         "250615",
#                         "250616",
#                         "250617",
#                         "250618",
#                         "250619",
#                         "250620",
#                         "250621",
#                         "250622",
#                         "250623",
#                         "250624",
#                         "250625",
#                         "250626",
#                         "250627",
#                         "250628",
#                         "250629",
#                         "250630",
#                         "250701",
#                         "250703",
#                         "250704",
#                         "250705",
#                         "250706",
#                         "250707",
#                         "250708",
#                         "250709",
#                         "250710",
#                         "250711",
#                         "250712",
#                         "250713",
#                         "250714",
#                         "250715",
#                         "250716",
#                         "250717",
#                         "250718",
#                         "250719",
#                         "250720",
#                         "250721",
#                         "250722",
#                         "250723",
#                         "250724",
#                         "250725",
#                         "250726",
#                         "250727",
#                         "250728",
#                         "250729",
#                         "250730",
#                         "250731",
#                         "250801",
#                         "250802"
#                     ],
#                     "sort_order": "asc",
#                     "step_name": "step0",
#                     "total_count": 74
#                 },
#                 "task_id": 1
#             },
#             {
#                 "console_output": "============================================================\n步骤0：获取所有可用数据目录的日期列表\n============================================================\n包含已处理日期信息: False\n排序方式: asc\n\n获取所有可用数据目录...\n数据目录: /bes3fs/offline/data/cal/round17\n找到 221 个可用日期目录\n日期列表: ['210220', '210221', '221110', '230413', '231029', '231030', '231031', '231101', '231102', '231103', '231104', '231105', '231106', '231107', '231108', '231109', '231110', '231111', '231112', '231113', '231114', '231115', '231116', '231117', '231118', '231119', '231120', '231121', '231122', '231123', '231124', '231125', '231126', '231127', '231128', '231129', '231130', '231201', '231202', '231203', '231204', '231205', '231206', '231207', '231208', '231209', '231210', '231211', '231212', '231213', '231214', '231215', '231216', '231217', '231218', '231219', '231220', '231221', '231222', '231223', '231224', '231225', '231226', '231227', '231228', '231229', '231230', '231231', '240101', '240102', '240103', '240104', '240105', '240106', '240107', '240108', '240109', '240110', '240111', '240112', '240113', '240114', '240115', '240116', '240117', '240118', '240119', '240120', '240121', '240122', '240123', '240124', '240125', '240126', '240127', '240128', '240129', '240130', '240131', '240201', '240202', '240203', '240204', '240205', '240206', '240207', '240208', '240209', '240210', '240211', '240212', '240213', '240214', '240215', '240216', '240217', '240218', '240219', '240220', '240221', '240222', '240223', '240224', '240225', '240226', '240227', '240228', '240229', '240301', '240302', '240303', '240304', '240305', '240306', '240307', '240308', '240309', '240310', '240311', '240312', '240313', '240314', '240315', '240316', '240317', '240318', '240319', '240320', '240321', '240322', '240323', '240324', '240325', '240326', '240327', '240328', '240404', '240405', '240406', '240407', '240408', '240409', '240410', '240411', '240412', '240413', '240414', '240415', '240416', '240417', '240418', '240419', '240420', '240421', '240422', '240423', '240424', '240425', '240426', '240427', '240428', '240429', '240430', '240501', '240502', '240503', '240504', '240505', '240506', '240507', '240508', '240509', '240510', '240511', '240512', '240513', '240514', '240515', '240516', '240517', '240518', '240519', '240520', '240521', '240522', '240523', '240524', '240525', '240526', '240527', '240528', '240529', '240530', '240531', '240601', '240602', '240603', '240604', '240605', '240606', '240607']\n\n统计信息:\n  总日期数: 221",
#                 "created_at": "2026-03-06T10:30:28.357855",
#                 "duration_seconds": 0,
#                 "end_time": "2026-03-06T10:30:28.525752",
#                 "error_details": null,
#                 "id": 2,
#                 "output_summary": "成功获取 221 个可用日期",
#                 "retry_count": 0,
#                 "start_time": "2026-03-06T10:30:28.357465",
#                 "status": "success",
#                 "step_display_name": "获取可用日期列表",
#                 "step_name": "step0",
#                 "step_order": 1,
#                 "step_result_json": {
#                     "all_dates": [
#                         "210220",
#                         "210221",
#                         "221110",
#                         "230413",
#                         "231029",
#                         "231030",
#                         "231031",
#                         "231101",
#                         "231102",
#                         "231103",
#                         "231104",
#                         "231105",
#                         "231106",
#                         "231107",
#                         "231108",
#                         "231109",
#                         "231110",
#                         "231111",
#                         "231112",
#                         "231113",
#                         "231114",
#                         "231115",
#                         "231116",
#                         "231117",
#                         "231118",
#                         "231119",
#                         "231120",
#                         "231121",
#                         "231122",
#                         "231123",
#                         "231124",
#                         "231125",
#                         "231126",
#                         "231127",
#                         "231128",
#                         "231129",
#                         "231130",
#                         "231201",
#                         "231202",
#                         "231203",
#                         "231204",
#                         "231205",
#                         "231206",
#                         "231207",
#                         "231208",
#                         "231209",
#                         "231210",
#                         "231211",
#                         "231212",
#                         "231213",
#                         "231214",
#                         "231215",
#                         "231216",
#                         "231217",
#                         "231218",
#                         "231219",
#                         "231220",
#                         "231221",
#                         "231222",
#                         "231223",
#                         "231224",
#                         "231225",
#                         "231226",
#                         "231227",
#                         "231228",
#                         "231229",
#                         "231230",
#                         "231231",
#                         "240101",
#                         "240102",
#                         "240103",
#                         "240104",
#                         "240105",
#                         "240106",
#                         "240107",
#                         "240108",
#                         "240109",
#                         "240110",
#                         "240111",
#                         "240112",
#                         "240113",
#                         "240114",
#                         "240115",
#                         "240116",
#                         "240117",
#                         "240118",
#                         "240119",
#                         "240120",
#                         "240121",
#                         "240122",
#                         "240123",
#                         "240124",
#                         "240125",
#                         "240126",
#                         "240127",
#                         "240128",
#                         "240129",
#                         "240130",
#                         "240131",
#                         "240201",
#                         "240202",
#                         "240203",
#                         "240204",
#                         "240205",
#                         "240206",
#                         "240207",
#                         "240208",
#                         "240209",
#                         "240210",
#                         "240211",
#                         "240212",
#                         "240213",
#                         "240214",
#                         "240215",
#                         "240216",
#                         "240217",
#                         "240218",
#                         "240219",
#                         "240220",
#                         "240221",
#                         "240222",
#                         "240223",
#                         "240224",
#                         "240225",
#                         "240226",
#                         "240227",
#                         "240228",
#                         "240229",
#                         "240301",
#                         "240302",
#                         "240303",
#                         "240304",
#                         "240305",
#                         "240306",
#                         "240307",
#                         "240308",
#                         "240309",
#                         "240310",
#                         "240311",
#                         "240312",
#                         "240313",
#                         "240314",
#                         "240315",
#                         "240316",
#                         "240317",
#                         "240318",
#                         "240319",
#                         "240320",
#                         "240321",
#                         "240322",
#                         "240323",
#                         "240324",
#                         "240325",
#                         "240326",
#                         "240327",
#                         "240328",
#                         "240404",
#                         "240405",
#                         "240406",
#                         "240407",
#                         "240408",
#                         "240409",
#                         "240410",
#                         "240411",
#                         "240412",
#                         "240413",
#                         "240414",
#                         "240415",
#                         "240416",
#                         "240417",
#                         "240418",
#                         "240419",
#                         "240420",
#                         "240421",
#                         "240422",
#                         "240423",
#                         "240424",
#                         "240425",
#                         "240426",
#                         "240427",
#                         "240428",
#                         "240429",
#                         "240430",
#                         "240501",
#                         "240502",
#                         "240503",
#                         "240504",
#                         "240505",
#                         "240506",
#                         "240507",
#                         "240508",
#                         "240509",
#                         "240510",
#                         "240511",
#                         "240512",
#                         "240513",
#                         "240514",
#                         "240515",
#                         "240516",
#                         "240517",
#                         "240518",
#                         "240519",
#                         "240520",
#                         "240521",
#                         "240522",
#                         "240523",
#                         "240524",
#                         "240525",
#                         "240526",
#                         "240527",
#                         "240528",
#                         "240529",
#                         "240530",
#                         "240531",
#                         "240601",
#                         "240602",
#                         "240603",
#                         "240604",
#                         "240605",
#                         "240606",
#                         "240607"
#                     ],
#                     "sort_order": "asc",
#                     "step_name": "step0",
#                     "total_count": 221
#                 },
#                 "task_id": 1
#             },
#             {
#                 "console_output": "run a do nothing step",
#                 "created_at": "2026-03-06T10:33:50.751545",
#                 "duration_seconds": 0,
#                 "end_time": "2026-03-06T10:33:50.758432",
#                 "error_details": null,
#                 "id": 3,
#                 "output_summary": "do nothing step finished",
#                 "retry_count": 0,
#                 "start_time": "2026-03-06T10:33:50.751245",
#                 "status": "success",
#                 "step_display_name": "展位符，用于pause_after的继续执行",
#                 "step_name": "step1",
#                 "step_order": 2,
#                 "step_result_json": {
#                     "step_name": "do_nothing",
#                     "step_nothing": "do_nothing"
#                 },
#                 "task_id": 1
#             }
#         ],
#         "id": 1,
#         "parameters": {
#             "include_processed": "False",
#             "round": "round17",
#             "sort_order": "asc",
#             "user_id": "user123"
#         },
#         "pause_at_step": "step0",
#         "progress_percentage": 100,
#         "resume_from_step": null,
#         "started_at": "2026-03-06T10:33:50.736222",
#         "status": "success",
#         "task_name": "获取可用日期列表",
#         "user_id": "user123",
#         "workflow_id": 3
#     }
# }

# %%
# hit the start endpoint for the task referenced by `base_url`
import requests

start_url = "http://127.0.0.1:5000/api/tasks/1/start"     # e.g. http://127.0.0.1:5000/api/tasks/1/start
resp = requests.post(start_url)  # send any needed params/body

print(resp.status_code, resp.text)
# Out:
# 200 {
#   "message": "Task started",
#   "success": true,
#   "task_id": 1
# }

# %%
# hit the start endpoint for the task referenced by `base_url`
import requests

start_url = "http://127.0.0.1:5000/api/tasks/1/resume"    # e.g. http://127.0.0.1:5000/api/tasks/1/start
body = {
    "parameters": {
        "round": "round17"
    }
}
resp = requests.post(start_url,json= body)  # send any needed params/body

print(resp.status_code, resp.text)
# Out:
# 200 {
#   "message": "Task resumed from step: step0",
#   "success": true
# }

# %%
start_url = "http://127.0.0.1:5000/api/tasks/1/resume"    # e.g. http://127.0.0.1:5000/api/tasks/1/start
body = {
    "retry_from_step": "step1"
}
resp = requests.post(start_url,json= body)  # send any needed params/body

print(resp.status_code, resp.text)
# Out:
# 200 {
#   "message": "Task resumed from step: step1",
#   "success": true
# }

# %%
# fetch error‑level logs for this task
import requests
base_url = "http://127.0.0.1:5000/api/tasks/1"  # e.g. http://
logs_url = f"{base_url}/logs"
query_params = {"limit": 100}

resp = requests.get(logs_url, params=query_params)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "logs": [
#         {
#             "created_at": "2026-03-06T07:39:49.596846",
#             "execution_id": 1,
#             "id": 1,
#             "level": "info",
#             "message": "Step 获取可用日期列表 completed successfully",
#             "source": "step_executor.step0",
#             "task_id": 1,
#             "timestamp": "2026-03-06T07:39:49.596842"
#         }
#     ],
#     "success": true,
#     "total": 1
# }

# %%
# fetch error‑level logs for this task
import requests
import json
base_url = "http://127.0.0.1:5000/api/workflows"  # e.g. http://


resp = requests.get(base_url)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "workflows": [
#         {
#             "config_path": "/home/iso/openclaw/topup2.0/HttpBackend/workflows/topup_standard.json",
#             "created_at": "2026-03-06T05:10:04.297764",
#             "description": "完整的数据处理流程，包含步骤1-8的所有子步骤",
#             "id": 1,
#             "name": "topup_standard_workflow",
#             "status": "active",
#             "updated_at": "2026-03-06T05:10:04.297768",
#             "version": "1.0.0"
#         },
#         {
#             "config_path": "/home/iso/openclaw/topup2.0/HttpBackend/workflows/topup_standard_steps.json",
#             "created_at": "2026-03-06T05:10:04.308181",
#             "description": "执行完整的Topup数据处理流程：第一次作业提交、移动文件、IST分析和图片合并",
#             "id": 2,
#             "name": "topup_standard_steps_workflow",
#             "status": "active",
#             "updated_at": "2026-03-06T05:10:04.308185",
#             "version": "1.0.1"
#         },
#         {
#             "config_path": "/home/iso/openclaw/topup2.0/HttpBackend/workflows/test_pause_resume.json",
#             "created_at": "2026-03-06T05:10:04.315613",
#             "description": "测试工作流的步骤级暂停和恢复功能，演示如何在步骤中触发暂停并通过API恢复",
#             "id": 3,
#             "name": "test_pause_resume_workflow",
#             "status": "active",
#             "updated_at": "2026-03-06T05:10:04.315616",
#             "version": "1.0.0"
#         },
#         {
#             "config_path": "/home/iso/openclaw/topup2.0/HttpBackend/workflows/get_available_dates.json",
#             "created_at": "2026-03-06T05:10:04.323678",
#             "description": "获取数据目录中所有可用的日期列表，并可选择包含已处理日期信息",
#             "id": 4,
#             "name": "get_available_dates_workflow",
#             "status": "active",
#             "updated_at": "2026-03-06T05:10:04.323682",
#             "version": "1.0.2"
#         }
#     ]
# }

# %%
# fetch error‑level logs for this task
import requests
import json
base_url = "http://127.0.0.1:5000/api/workflows/test_pause_resume_workflow"  # e.g. http://

resp = requests.get(base_url)
resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 200 {
#     "success": true,
#     "workflow": {
#         "description": "测试工作流的步骤级暂停和恢复功能，演示如何在步骤中触发暂停并通过API恢复",
#         "execution_config": {
#             "cleanup_on_failure": false,
#             "cleanup_on_success": false,
#             "continue_on_error": false,
#             "default_timeout_minutes": 10,
#             "max_parallel_tasks": 1,
#             "max_retries": 0,
#             "retry_delay_seconds": 0,
#             "retry_on_failure": false
#         },
#         "name": "test_pause_resume_workflow",
#         "parameters_config": {
#             "optional": [
#                 {
#                     "default": "initial_value",
#                     "description": "测试参数，可以在暂停后通过API修改",
#                     "name": "test_param",
#                     "type": "string"
#                 },
#                 {
#                     "default": true,
#                     "description": "是否在第一步触发暂停（true=暂停，false=直接执行）",
#                     "name": "should_pause",
#                     "type": "boolean"
#                 }
#             ],
#             "required": [
#                 "user_id"
#             ]
#         },
#         "steps": [
#             {
#                 "description": "第一步，根据should_pause参数决定是否触发暂停",
#                 "display_name": "步骤1：暂停测试",
#                 "function": "step_test_pause",
#                 "id": "step1_pause",
#                 "module": "test.test_pause_resume",
#                 "order": 1,
#                 "parameters": {
#                     "should_pause": "should_pause",
#                     "test_param": "test_param"
#                 },
#                 "retry_count": 0,
#                 "timeout_minutes": 10
#             },
#             {
#                 "description": "第二步，使用更新后的参数继续执行",
#                 "display_name": "步骤2：继续执行",
#                 "function": "step_test_continue",
#                 "id": "step2_continue",
#                 "module": "test.test_pause_resume",
#                 "order": 2,
#                 "parameters": {
#                     "test_param": "test_param"
#                 },
#                 "retry_count": 0,
#                 "timeout_minutes": 5
#             },
#             {
#                 "description": "第三步，完成整个测试流程",
#                 "display_name": "步骤3：最终步骤",
#                 "function": "step_test_final",
#                 "id": "step3_final",
#                 "module": "test.test_pause_resume",
#                 "order": 3,
#                 "parameters": {},
#                 "retry_count": 0,
#                 "timeout_minutes": 5
#             }
#         ],
#         "version": "1.0.0"
#     }
# }

# %%
import requests
import json

url = "http://127.0.0.1:5000/api/tasks"  # 修改为实际的地址
payload = {
    "user_id": "user123",
    "workflow_name": "topup_standard_steps_workflow",
    "task_name": "step1测试",
    "parameters": {
        "user_id": "user123",
        "submit_job": True,
        "check_ist" : True,
        "max_wait_minutes": 30,
        "download_files" : True,
        "date" : 250519,
        "round": "round18"
    }
}

resp = requests.post(url, json=payload)  # requests 会自动设置 Content-Type: application/json


resp_text = json.loads(resp.text)
print(resp.status_code, json.dumps(resp_text, ensure_ascii=False, indent=4))
# Out:
# 201 {
#     "message": "Task created successfully",
#     "status": "pending",
#     "success": true,
#     "task": {
#         "completed_at": null,
#         "created_at": "2026-03-01T10:25:07.016327",
#         "current_step": null,
#         "date_param": null,
#         "error_message": null,
#         "estimated_completion_time": null,
#         "id": 1,
#         "progress_percentage": 0,
#         "started_at": null,
#         "status": "pending",
#         "task_name": "step1测试",
#         "user_id": "user123",
#         "workflow_id": 1
#     },
#     "task_id": 1
# }
